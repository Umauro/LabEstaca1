# %% [markdown]
# # Piedra, papel o tijeras
#
# Para escoger de forma aleatoria se considera utilizar random.randint(1,3) y asociar piedra, papel y tijeras a los valores 1, 2 y 3 del random respectivamente.
#
# Para el problema, se hace comparación en los 9 casos posibles (3 por estrategia) teniendo un total de 3000 duelos por estrategia.

# %%
import random
wins=0

#Caso A vs A
for i in range(0,1000):
    a=random.randint(1,3)
    e=random.randint(1,3)
    if (a==1) and (e==3):
        wins=wins+1
    elif (a==2) and (e==1):
        wins=wins+1
    elif (a==3) and (e==2):
        wins=wins+1
        
#Caso A vs B
e=random.randint(1,3)
for i in range(0,1000):
    a=random.randint(1,3)
    if (a==1) and (e==3):
        wins=wins+1
        e=random.randint(1,3)
    elif (a==2) and (e==1):
        wins=wins+1
        e=random.randint(1,3)
    elif (a==3) and (e==2):
        wins=wins+1
        e=random.randint(1,3)
    elif (a==e):
        e=random.randint(1,3)
        
#Caso A vs C
e=random.randint(1,3)
for i in range(0,1000):
    a=random.randint(1,3)
    if (a==1) and (e==3):
        wins=wins+1
        e=2
    elif (a==2) and (e==1):
        wins=wins+1
        e=3
    elif (a==3) and (e==2):
        wins=wins+1
        e=1
    elif (a==e):
        if (e==3):
            e=2
        elif (e==2):
            e=1
        elif (e==1):
            e=3

print("La cantidad de victorias fue: "+str(wins))
print("El porcentaje de victoria para la estrategia A fue de un: "+str(wins/30)+"%")
# Out:
# La cantidad de victorias fue: 989
# El porcentaje de victoria para la estrategia A fue de un: 32.96666666666667%

# %%
wins=0

#Caso B vs A

a=random.randint(1,3)
for i in range(0,1000):
    e=random.randint(1,3)
    if (a==1) and (e==3):
        wins=wins+1
    elif (a==2) and (e==1):
        wins=wins+1
    elif (a==3) and (e==2):
        wins=wins+1
    elif (a!=e):
        a=random.randint(1,3)
        
#Caso B vs B
e=random.randint(1,3)
a=random.randint(1,3)
for i in range(0,1000):
    if (a==1) and (e==3):
        wins=wins+1
        e=random.randint(1,3)
    elif (a==2) and (e==1):
        wins=wins+1
        e=random.randint(1,3)
    elif (a==3) and (e==2):
        wins=wins+1
        e=random.randint(1,3)
    elif (a==e):
        e=random.randint(1,3)
    elif (a!=e):
        a=random.randint(1,3)

        
#Caso B vs C
a=random.randint(1,3)
e=random.randint(1,3)
for i in range(0,1000):
    if (a==1) and (e==3):
        wins=wins+1
        e=2
    elif (a==2) and (e==1):
        wins=wins+1
        e=3
    elif (a==3) and (e==2):
        wins=wins+1
        e=1
    elif (a==e):
        if (e==3):
            e=2
        elif (e==2):
            e=1
        elif (e==1):
            e=3
    elif (a!=e):
        a=random.randint(1,3)
        

print("La cantidad de victorias fue: "+str(wins))
print("El porcentaje de victoria para la estrategia B fue de un: "+str(wins/30)+"%")
# Out:
# La cantidad de victorias fue: 1001
# El porcentaje de victoria para la estrategia B fue de un: 33.36666666666667%

# %%
wins=0

#Caso C vs A

a=random.randint(1,3)
for i in range(0,1000):
    e=random.randint(1,3)
    if (a==1) and (e==3):
        wins=wins+1
    elif (a==2) and (e==1):
        wins=wins+1
    elif (a==3) and (e==2):
        wins=wins+1
    elif (a!=e):
        if (a==3):
            a=1
        elif (a==2):
            a=3
        elif (a==1):
            a=2
        
#Caso C vs B
e=random.randint(1,3)
a=random.randint(1,3)
for i in range(0,1000):
    if (a==1) and (e==3):
        wins=wins+1
        e=random.randint(1,3)
    elif (a==2) and (e==1):
        wins=wins+1
        e=random.randint(1,3)
    elif (a==3) and (e==2):
        wins=wins+1
        e=random.randint(1,3)
    elif (a==e):
        e=random.randint(1,3)
    elif (a!=e):
        if (a==3):
            a=1
        elif (a==2):
            a=3
        elif (a==1):
            a=2

        
#Caso C vs C
a=random.randint(1,3)
e=random.randint(1,3)
for i in range(0,1000):
    if (a==1) and (e==3):
        wins=wins+1
        e=2
    elif (a==2) and (e==1):
        wins=wins+1
        e=3
    elif (a==3) and (e==2):
        wins=wins+1
        e=1
    elif (a==e):
        if (e==3):
            e=2
        elif (e==2):
            e=1
        elif (e==1):
            e=3
    elif (a!=e):
        if (a==3):
            a=1
        elif (a==2):
            a=3
        elif (a==1):
            a=2
        

print("La cantidad de victorias fue: "+str(wins))
print("El porcentaje de victoria para la estrategia C fue de un: "+str(wins/30)+"%")
# Out:
# La cantidad de victorias fue: 895
# El porcentaje de victoria para la estrategia C fue de un: 29.833333333333332%

# %% [markdown]
# Dado que en cualquiera de las 3 estrategias se estan usando valores aleatorios para comparar, los porcentajes de victoria variarán cada vez que se ejecute el código y no se podría determinar una estrategia favorable sobre la otra debido a esto.
#
# Si se considerara los resultados obtenidos en varias ejecuciones, se puede observar que la estrategia C tiende a tomar valores un 1-4% menores a los que toman las estrategias A y B (esto no ocurre siempre debido a las variables aleatorias), siendo una de estas la que toma el mejor porcentaje de victoria por una diferencia minima.
